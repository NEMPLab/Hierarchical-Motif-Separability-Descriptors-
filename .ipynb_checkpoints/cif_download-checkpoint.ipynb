# %%
import os
import re
import pandas as pd
from mp_api.client import MPRester

def extract_elements(formula):
    elements = re.findall(r'[A-Z][a-z]?', formula)  # 提取元素
    return ", ".join(elements)

def get_materials_data(apikey="", force_update=False):
    filepath = '/home/gaotianjiao/modnet-master/ext_struc/spinels.csv'

    if os.path.exists(filepath) and not force_update:
        print("Loading data from existing CSV file.")
        return pd.read_csv(filepath, index_col=0)

    if not apikey:
        print('------------  Please input your API key! ---------------')
        return None

    result = []
    with MPRester(apikey) as m:
        spacegroup_numbers = list(range(198, 231))
        anions = ['O', 'S', 'Se', 'Te', 'Cl', 'F']

        for spacegroup in spacegroup_numbers:
            for anion in anions:
                try:
                    docs = m.materials.summary.search(
                        formula=f'*1*2{anion}4',
                        spacegroup_number=spacegroup,
                        fields=[
                            "material_id",          # ✅ 新增字段
                            "formula_pretty", 
                            "structure", 
                            "elements", 
                            "nsites",
                            "volume", 
                            "density",
                            "symmetry.number", 
                            "symmetry.symbol",
                            "formation_energy_per_atom",
                            "energy_above_hull",
                            "possible_species",
                            "band_gap",
                            "cbm",
                            "vbm"
                        ]
                    )
                except Exception as e:
                    print(f"Error during API request for spacegroup {spacegroup} and anion {anion}: {e}")
                    continue

                if docs:
                    for doc in docs:
                        elements_str = extract_elements(doc.formula_pretty)

                        lattice_a = doc.structure.lattice.a
                        lattice_b = doc.structure.lattice.b
                        lattice_c = doc.structure.lattice.c
                        lattice_alpha = doc.structure.lattice.alpha
                        lattice_beta = doc.structure.lattice.beta
                        lattice_gamma = doc.structure.lattice.gamma

                        volume = doc.volume
                        # 修正 Fm-3m / Fd-3m 晶格常数和体积
                        if doc.symmetry.symbol in ["Fm-3m", "Fd-3m"]:
                            lattice_a *= (2**0.5)
                            volume *= 4

                        # 提取带隙信息
                        band_gap = doc.band_gap
                        cbm = doc.cbm
                        vbm = doc.vbm

                        # 提取晶体结构信息
                        structure = doc.structure.as_dict()

                        result.append({
                            "id": doc.material_id,  # ✅ 新增材料 ID
                            "formula": doc.formula_pretty,
                            "space_group": doc.symmetry.number,
                            "symmetry_symbol": doc.symmetry.symbol,
                            "lattice_a": lattice_a,
                            "lattice_b": lattice_b,
                            "lattice_c": lattice_c,
                            "lattice_alpha": lattice_alpha,
                            "lattice_beta": lattice_beta,
                            "lattice_gamma": lattice_gamma,
                            "elements": elements_str,
                            "sites": doc.nsites,
                            "volume": volume,
                            "density": doc.density,
                            "formation_energy_per_atom": doc.formation_energy_per_atom,
                            "energy_above_hull": doc.energy_above_hull,
                            "possible_species": doc.possible_species,
                            "band_gap": band_gap,
                            "cbm": cbm,
                            "vbm": vbm,
                            "structure": structure
                        })

    materials_df = pd.DataFrame(result)
    if not materials_df.empty:
        materials_df = materials_df.sort_values(by="space_group")
        os.makedirs(os.path.dirname(filepath), exist_ok=True)
        materials_df.to_csv(filepath, index=False)
        print(f"Data saved to {filepath}")
    else:
        print("No data retrieved from the API.")

    return materials_df

# -------------------- 运行 --------------------
materials_data = get_materials_data('7PYF7c0DvFXufDMo1DL6yLZQbv7ZMpNp')
print(materials_data.head())
# Out:
# /home/gaotianjiao/anaconda3/envs/python3.10/lib/python3.10/site-packages/pybtex/plugin/__init__.py:26: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Loading data from existing CSV file.
#               formula  space_group symmetry_symbol  lattice_a  lattice_b  \
# id
# mp-578931     Cu2SeO4          198           P2_13   9.031504   9.031504
# mp-1201604     Cd2BO4          203            Fd-3  10.001948  10.001948
# mp-13827     Ca(BO2)2          205            Pa-3   9.088439   9.088439
# mp-8878      Sr(BO2)2          205            Pa-3   9.219764   9.219764
# mp-14246    Ba(AlS2)2          205            Pa-3  12.732061  12.732061
#
#             lattice_c  lattice_alpha  lattice_beta  lattice_gamma   elements  \
# id
# mp-578931    9.031504           90.0          90.0           90.0  Cu, Se, O
# mp-1201604  10.001948           60.0          60.0           60.0   Cd, B, O
# mp-13827     9.088439           90.0          90.0           90.0   Ca, B, O
# mp-8878      9.219764           90.0          90.0           90.0   Sr, B, O
# mp-14246    12.732061           90.0          90.0           90.0  Ba, Al, S
#
#             sites       volume   density  formation_energy_per_atom  \
# id
# mp-578931      56   736.682301  4.869702                  -1.041948
# mp-1201604     56   707.520018  5.625829                  -1.721708
# mp-13827       84   750.702548  3.336487                  -3.087739
# mp-8878        84   783.717248  4.404718                  -3.088624
# mp-14246       84  2063.935421  3.085128                  -1.754766
#
#             energy_above_hull              possible_species  band_gap     cbm  \
# id
# mp-578931            0.009928       ['O2-', 'Se4+', 'Cu2+']    0.3242  3.2507
# mp-1201604           0.109697  ['Cd2+', 'O2-', 'B3+', 'O-']    1.2871  2.6732
# mp-13827             0.040862        ['Ca2+', 'O2-', 'B3+']    6.0926  9.2503
# mp-8878              0.034495        ['O2-', 'Sr2+', 'B3+']    6.3968  9.2064
# mp-14246             0.000000       ['S2-', 'Al3+', 'Ba2+']    3.6551  6.0726
#
#                vbm                                          structure
# id
# mp-578931   2.9265  {'@module': 'pymatgen.core.structure', '@class...
# mp-1201604  1.3861  {'@module': 'pymatgen.core.structure', '@class...
# mp-13827    3.1577  {'@module': 'pymatgen.core.structure', '@class...
# mp-8878     2.8096  {'@module': 'pymatgen.core.structure', '@class...
# mp-14246    2.4175  {'@module': 'pymatgen.core.structure', '@class...

# %%
import os
import pandas as pd
from mp_api.client import MPRester

def download_cif_from_ids(apikey, csv_path, save_dir="./spinels_cif"):
    if not os.path.exists(csv_path):
        print(f"❌ 未找到文件: {csv_path}")
        return

    os.makedirs(save_dir, exist_ok=True)
    df = pd.read_csv(csv_path)

    if "id" not in df.columns:
        print("❌ CSV 中没有 'id' 列！请确保已包含材料 ID（mp-xxxx）。")
        return

    ids = df["id"].dropna().unique().tolist()
    print(f"🔍 共检测到 {len(ids)} 个材料 ID，将开始下载...")

    with MPRester(apikey) as m:
        # 检查可用接口（不同版本 mp_api 兼容）
        has_materials_structure = hasattr(m.materials, "structure")
        has_structures = hasattr(m, "structures")
        has_get_structure = hasattr(m, "get_structure_by_material_id")

        for mid in ids:
            cif_path = os.path.join(save_dir, f"{mid}.cif")
            if os.path.exists(cif_path):
                print(f"已存在: {cif_path}")
                continue

            try:
                # ✅ 尝试使用不同版本接口
                if has_materials_structure:
                    structure_doc = m.materials.structure.get(mid, conventional_unit_cell=True)
                    structure = structure_doc.structure
                elif has_structures:
                    structure_doc = m.structures.get_data_by_id(mid)
                    structure = structure_doc[0].structure
                elif has_get_structure:
                    structure = m.get_structure_by_material_id(mid)
                else:
                    raise RuntimeError("未找到合适的结构接口，请更新 mp_api 包。")

                cif_str = structure.to(fmt="cif")
                with open(cif_path, "w") as f:
                    f.write(cif_str)
                print(f"✅ 已保存 CIF: {cif_path}")

            except Exception as e:
                print(f"❌ 下载失败 {mid}: {e}")

    print("全部下载完成！")

if __name__ == "__main__":
    API_KEY = "7PYF7c0DvFXufDMo1DL6yLZQbv7ZMpNp"  
    CSV_PATH = "/home/gaotianjiao/modnet-master/ext_struc/spinels.csv"
    SAVE_DIR = "/home/gaotianjiao/modnet-master/ext_struc/spinels_cif"

    download_cif_from_ids(API_KEY, CSV_PATH, SAVE_DIR)
# Out:
# 🔍 共检测到 332 个材料 ID，将开始下载...
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-578931.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1201604.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-13827.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-8878.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-14246.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-30958.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-849286.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-774941.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-773076.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mvc-14772.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1222624.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-2221507.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1246286.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1388111.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1389421.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1247073.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1238859.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1238886.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1247104.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1238779.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232170.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1238827.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1238805.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232294.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232096.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1400406.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232131.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232270.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1247043.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1394188.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1390164.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1395289.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1443364.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-14307.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1443666.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1446454.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-14305.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1410970.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1408976.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1395193.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1402738.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-14304.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-14306.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-14025.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232246.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1400392.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1390919.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1389718.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1411384.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232279.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232111.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232045.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1045397.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1045358.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1045384.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1045401.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1045348.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1001012.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1040470.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1001015.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-973261.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-770957.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-772214.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-7831.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-768600.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-770107.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-768465.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-756851.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-768586.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232129.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1001024.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-10754.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232114.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232281.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1232112.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-15065.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1212041.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1104381.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1104162.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1094002.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1104053.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1104783.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1104382.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp-1103852.cif
# 已存在: /home/gaotianjiao/modnet-master/ext_struc/spinels_cif/mp